# %%
# %reload_ext autoreload
# %autoreload 2
import sys
import pandas as pd
sys.path.append('../code/')
import sfanalysis as sf
import matplotlib.pyplot as plt
from visualisations import *

# %%
gml_dir = 'gmls/'
deg_dir = 'degseqs/'

# %%
deg_df = sf.write_degree_sequences(gml_dir, deg_dir)
deg_df.head()
# Out:
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# gmls/original/graph_target_cleaned.gml
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# graph_target_cleaned.gml_directedindistribution.txt mean degree is too small
#
# graph_target_cleaned.gml_directedoutdistribution.txt mean degree is too small
#
# gmls/original/graph_intro_cleaned.gml
# graph_intro_cleaned.gml_directedindistribution.txt mean degree is too small
#
# graph_intro_cleaned.gml_directedoutdistribution.txt mean degree is too small
#
# gmls/original/graph_make_cleaned.gml
# gmls/original/graph_maze_cleaned.gml
# graph_maze_cleaned.gml_directedindistribution.txt mean degree is too small
#
# graph_maze_cleaned.gml_directedoutdistribution.txt mean degree is too small
#
# gmls/original/graph_base_cleaned.gml
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# graph_base_cleaned.gml_directedindistribution.txt mean degree is too small
#
# graph_base_cleaned.gml_directedoutdistribution.txt mean degree is too small
#
# gmls/original/graph_tutorial_cleaned.gml
# graph_tutorial_cleaned.gml_directedindistribution.txt mean degree is too small
#
# graph_tutorial_cleaned.gml_directedoutdistribution.txt mean degree is too small
#
# gmls/original/graph_helper_cleaned.gml
# graph_helper_cleaned.gml_directedindistribution.txt mean degree is too small
#
# graph_helper_cleaned.gml_directedoutdistribution.txt mean degree is too small
#
# gmls/original/graph_break_cleaned.gml
# graph_break_cleaned.gml_directedindistribution.txt mean degree is too small
#
# graph_break_cleaned.gml_directedoutdistribution.txt mean degree is too small
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'edge_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
# /home/vani/anaconda3/envs/graphvis/lib/python3.9/site-packages/igraph/io/files.py:295: RuntimeWarning: Composite graph attribute 'node_default' ignored in GML file. at src/io/gml.c:361
#   return reader(f, *args, **kwds)
#                                                    num_edges Weighted  \
# graph_target_cleaned.gml_directedtotaldistribut...    162581        0
# graph_intro_cleaned.gml_directedtotaldistributi...      7911        0
# graph_make_cleaned.gml_directedindistribution.txt       5803        0
# graph_make_cleaned.gml_directedoutdistribution.txt      5803        0
# graph_make_cleaned.gml_directedtotaldistributio...      5803        0
#
#                                                    Directed Bipartite  \
# graph_target_cleaned.gml_directedtotaldistribut...    total         0
# graph_intro_cleaned.gml_directedtotaldistributi...    total         0
# graph_make_cleaned.gml_directedindistribution.txt        in         0
# graph_make_cleaned.gml_directedoutdistribution.txt      out         0
# graph_make_cleaned.gml_directedtotaldistributio...    total         0
#
#                                                    Multigraph Multiplex  \
# graph_target_cleaned.gml_directedtotaldistribut...          0         0
# graph_intro_cleaned.gml_directedtotaldistributi...          0         0
# graph_make_cleaned.gml_directedindistribution.txt           0         0
# graph_make_cleaned.gml_directedoutdistribution.txt          0         0
# graph_make_cleaned.gml_directedtotaldistributio...          0         0
#
#                                                                                     fp_gml  \
# graph_target_cleaned.gml_directedtotaldistribut...  gmls/original/graph_target_cleaned.gml
# graph_intro_cleaned.gml_directedtotaldistributi...   gmls/original/graph_intro_cleaned.gml
# graph_make_cleaned.gml_directedindistribution.txt     gmls/original/graph_make_cleaned.gml
# graph_make_cleaned.gml_directedoutdistribution.txt    gmls/original/graph_make_cleaned.gml
# graph_make_cleaned.gml_directedtotaldistributio...    gmls/original/graph_make_cleaned.gml
#
#                                                    n alpha xmin ntail Lpl ppl  \
# graph_target_cleaned.gml_directedtotaldistribut...
# graph_intro_cleaned.gml_directedtotaldistributi...
# graph_make_cleaned.gml_directedindistribution.txt
# graph_make_cleaned.gml_directedoutdistribution.txt
# graph_make_cleaned.gml_directedtotaldistributio...
#
#                                                    dexp dln dstrexp dplwc  \
# graph_target_cleaned.gml_directedtotaldistribut...
# graph_intro_cleaned.gml_directedtotaldistributi...
# graph_make_cleaned.gml_directedindistribution.txt
# graph_make_cleaned.gml_directedoutdistribution.txt
# graph_make_cleaned.gml_directedtotaldistributio...
#
#                                                      meandeg
# graph_target_cleaned.gml_directedtotaldistribut...   2.45509
# graph_intro_cleaned.gml_directedtotaldistributi...  2.480715
# graph_make_cleaned.gml_directedindistribution.txt   2.262378
# graph_make_cleaned.gml_directedoutdistribution.txt  2.262378
# graph_make_cleaned.gml_directedtotaldistributio...  4.524756

# %%
analysis_df = sf.analyze_degree_sequences(deg_dir, deg_df)
# Out:
# p = 0.000   elapsed time = 39.53856563568115
# p = 0.000   elapsed time = 2.2095112800598145
# p = 0.000   elapsed time = 0.8812766075134277
# p = 0.000   elapsed time = 0.8647987842559814
# p = 0.000   elapsed time = 1.3380815982818604
# p = 0.006   elapsed time = 2.175274610519409
# p = 0.000   elapsed time = 40.16730356216431
# p = 0.525   elapsed time = 2.7079215049743652
# p = 0.000   elapsed time = 25.780155420303345
# p = 0.000   elapsed time = 2.6350622177124023

# %%
analysis_df
# Out:
#                                                    num_edges Weighted  \
# graph_target_cleaned.gml_directedtotaldistribut...    162581        0
# graph_intro_cleaned.gml_directedtotaldistributi...      7911        0
# graph_make_cleaned.gml_directedindistribution.txt       5803        0
# graph_make_cleaned.gml_directedoutdistribution.txt      5803        0
# graph_make_cleaned.gml_directedtotaldistributio...      5803        0
# graph_maze_cleaned.gml_directedtotaldistributio...      9621        0
# graph_base_cleaned.gml_directedtotaldistributio...    155467        0
# graph_tutorial_cleaned.gml_directedtotaldistrib...     11074        0
# graph_helper_cleaned.gml_directedtotaldistribut...     93210        0
# graph_break_cleaned.gml_directedtotaldistributi...     12361        0
#
#                                                    Directed Bipartite  \
# graph_target_cleaned.gml_directedtotaldistribut...    total         0
# graph_intro_cleaned.gml_directedtotaldistributi...    total         0
# graph_make_cleaned.gml_directedindistribution.txt        in         0
# graph_make_cleaned.gml_directedoutdistribution.txt      out         0
# graph_make_cleaned.gml_directedtotaldistributio...    total         0
# graph_maze_cleaned.gml_directedtotaldistributio...    total         0
# graph_base_cleaned.gml_directedtotaldistributio...    total         0
# graph_tutorial_cleaned.gml_directedtotaldistrib...    total         0
# graph_helper_cleaned.gml_directedtotaldistribut...    total         0
# graph_break_cleaned.gml_directedtotaldistributi...    total         0
#
#                                                    Multigraph Multiplex  \
# graph_target_cleaned.gml_directedtotaldistribut...          0         0
# graph_intro_cleaned.gml_directedtotaldistributi...          0         0
# graph_make_cleaned.gml_directedindistribution.txt           0         0
# graph_make_cleaned.gml_directedoutdistribution.txt          0         0
# graph_make_cleaned.gml_directedtotaldistributio...          0         0
# graph_maze_cleaned.gml_directedtotaldistributio...          0         0
# graph_base_cleaned.gml_directedtotaldistributio...          0         0
# graph_tutorial_cleaned.gml_directedtotaldistrib...          0         0
# graph_helper_cleaned.gml_directedtotaldistribut...          0         0
# graph_break_cleaned.gml_directedtotaldistributi...          0         0
#
#                                                                                       fp_gml  \
# graph_target_cleaned.gml_directedtotaldistribut...    gmls/original/graph_target_cleaned.gml
# graph_intro_cleaned.gml_directedtotaldistributi...     gmls/original/graph_intro_cleaned.gml
# graph_make_cleaned.gml_directedindistribution.txt       gmls/original/graph_make_cleaned.gml
# graph_make_cleaned.gml_directedoutdistribution.txt      gmls/original/graph_make_cleaned.gml
# graph_make_cleaned.gml_directedtotaldistributio...      gmls/original/graph_make_cleaned.gml
# graph_maze_cleaned.gml_directedtotaldistributio...      gmls/original/graph_maze_cleaned.gml
# graph_base_cleaned.gml_directedtotaldistributio...      gmls/original/graph_base_cleaned.gml
# graph_tutorial_cleaned.gml_directedtotaldistrib...  gmls/original/graph_tutorial_cleaned.gml
# graph_helper_cleaned.gml_directedtotaldistribut...    gmls/original/graph_helper_cleaned.gml
# graph_break_cleaned.gml_directedtotaldistributi...     gmls/original/graph_break_cleaned.gml
#
#                                                          n alpha xmin  ntail  \
# graph_target_cleaned.gml_directedtotaldistribut...  132444  5.01    4  20375
# graph_intro_cleaned.gml_directedtotaldistributi...    6378  5.17    4   1106
# graph_make_cleaned.gml_directedindistribution.txt     2565  5.75    3    898
# graph_make_cleaned.gml_directedoutdistribution.txt    2565  5.97    3    906
# graph_make_cleaned.gml_directedtotaldistributio...    2565  7.15    6    811
# graph_maze_cleaned.gml_directedtotaldistributio...    6933  8.79    6    353
# graph_base_cleaned.gml_directedtotaldistributio...  131926  5.79    4  16407
# graph_tutorial_cleaned.gml_directedtotaldistrib...    9853   9.2    6    122
# graph_helper_cleaned.gml_directedtotaldistribut...   83787  6.61    4   7543
# graph_break_cleaned.gml_directedtotaldistributi...    8624  7.32    6    862
#
#                                                              Lpl    ppl dexp  \
# graph_target_cleaned.gml_directedtotaldistribut... -24241.942503    0.0   -1
# graph_intro_cleaned.gml_directedtotaldistributi...  -1267.770809    0.0    0
# graph_make_cleaned.gml_directedindistribution.txt    -666.493031    0.0   -1
# graph_make_cleaned.gml_directedoutdistribution.txt   -633.739271    0.0   -1
# graph_make_cleaned.gml_directedtotaldistributio...   -904.915021    0.0   -1
# graph_maze_cleaned.gml_directedtotaldistributio...   -309.224172  0.006   -1
# graph_base_cleaned.gml_directedtotaldistributio...  -16325.56761    0.0    1
# graph_tutorial_cleaned.gml_directedtotaldistrib...   -100.814587  0.525    0
# graph_helper_cleaned.gml_directedtotaldistribut...  -6287.145562    0.0    1
# graph_break_cleaned.gml_directedtotaldistributi...   -937.129534    0.0   -1
#
#                                                    dln dstrexp dplwc   meandeg
# graph_target_cleaned.gml_directedtotaldistribut...  -1      -1    -1   2.45509
# graph_intro_cleaned.gml_directedtotaldistributi...  -1      -1    -1  2.480715
# graph_make_cleaned.gml_directedindistribution.txt   -1      -1    -1  2.262378
# graph_make_cleaned.gml_directedoutdistribution.txt  -1      -1    -1  2.262378
# graph_make_cleaned.gml_directedtotaldistributio...  -1      -1    -1  4.524756
# graph_maze_cleaned.gml_directedtotaldistributio...  -1      -1    -1  2.775422
# graph_base_cleaned.gml_directedtotaldistributio...  -1      -1    -1  2.356882
# graph_tutorial_cleaned.gml_directedtotaldistrib...  -1      -1     0  2.247843
# graph_helper_cleaned.gml_directedtotaldistribut...  -1      -1     0  2.224927
# graph_break_cleaned.gml_directedtotaldistributi...  -1      -1    -1  2.866651

# %%
hyps_df = sf.categorize_networks(analysis_df)
hyps_df
# Out:
#                                          Strongest Strong   Weak Weakest  \
# gmls/original/graph_base_cleaned.gml         False  False  False   False
# gmls/original/graph_break_cleaned.gml        False  False  False   False
# gmls/original/graph_helper_cleaned.gml       False  False  False   False
# gmls/original/graph_intro_cleaned.gml        False  False  False   False
# gmls/original/graph_make_cleaned.gml         False  False  False   False
# gmls/original/graph_maze_cleaned.gml         False  False  False   False
# gmls/original/graph_target_cleaned.gml       False  False  False   False
# gmls/original/graph_tutorial_cleaned.gml     False  False   True    True
#
#                                          Super_Weak median_alpha       n  \
# gmls/original/graph_base_cleaned.gml          False         5.79  131926
# gmls/original/graph_break_cleaned.gml         False         7.32    8624
# gmls/original/graph_helper_cleaned.gml        False         6.61   83787
# gmls/original/graph_intro_cleaned.gml         False         5.17    6378
# gmls/original/graph_make_cleaned.gml          False         5.97    2565
# gmls/original/graph_maze_cleaned.gml          False         8.79    6933
# gmls/original/graph_target_cleaned.gml        False         5.01  132444
# gmls/original/graph_tutorial_cleaned.gml      False          9.2    9853
#
#                                          median_ntail
# gmls/original/graph_base_cleaned.gml          16407.0
# gmls/original/graph_break_cleaned.gml           862.0
# gmls/original/graph_helper_cleaned.gml         7543.0
# gmls/original/graph_intro_cleaned.gml          1106.0
# gmls/original/graph_make_cleaned.gml            898.0
# gmls/original/graph_maze_cleaned.gml            353.0
# gmls/original/graph_target_cleaned.gml        20375.0
# gmls/original/graph_tutorial_cleaned.gml        122.0

# %%
fig, ax = plt.subplots(figsize=(5,3.5))

make_domain_ploth(ax, hyps_df, True)
ax.text(-0.4, 10, 'All data sets' , fontsize=LABEL_SIZE, rotation=90, va='bottom')
plt.show()
